# %%
import pandas as pd

# %%
data= pd.read_csv("kc_house_data.csv")

# %%
data
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
data.shape
# Out:
# (21597, 21)

# %%
data["id"].value_counts()
# Out:
# 795000620     3
# 8910500150    2
# 7409700215    2
# 1995200200    2
# 9211500620    2
#              ..
# 3649100387    1
# 2767603649    1
# 1446403617    1
# 5602000275    1
# 1523300157    1
# Name: id, Length: 21420, dtype: int64

# %%
data= data.drop(["id"],axis=1)         #  lets  drop the id , id is not varry

# %%
data.head()
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  10/13/2014  221900.0         3       1.00         1180      5650     1.0
# 1   12/9/2014  538000.0         3       2.25         2570      7242     2.0
# 2   2/25/2015  180000.0         2       1.00          770     10000     1.0
# 3   12/9/2014  604000.0         4       3.00         1960      5000     1.0
# 4   2/18/2015  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
data["date"].value_counts()
# Out:
# 6/23/2014    142
# 6/25/2014    131
# 6/26/2014    131
# 7/8/2014     127
# 4/27/2015    126
#             ...
# 11/2/2014      1
# 1/31/2015      1
# 5/24/2015      1
# 5/17/2014      1
# 7/27/2014      1
# Name: date, Length: 372, dtype: int64

# %%
21597 / 372
# Out:
# 58.056451612903224

# %% [markdown]
# # lets do LabelEncoder  of date

# %%
from sklearn.preprocessing import LabelEncoder
k = LabelEncoder()
data["date"] = k.fit_transform(data['date'])

# %%
data.head(5)
# Out:
#    date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0    30  221900.0         3       1.00         1180      5650     1.0
# 1   114  538000.0         3       2.25         2570      7242     2.0
# 2   132  180000.0         2       1.00          770     10000     1.0
# 3   114  604000.0         4       3.00         1960      5000     1.0
# 4   124  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
x= data.drop("price", axis=1)         # x is feature
x.head()
# Out:
#    date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0    30         3       1.00         1180      5650     1.0           0     0
# 1   114         3       2.25         2570      7242     2.0           0     0
# 2   132         2       1.00          770     10000     1.0           0     0
# 3   114         4       3.00         1960      5000     1.0           0     0
# 4   124         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
# 3          5      7        1050            910      1965             0
# 4          3      8        1680              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
y= data["price"]
y                          #  y is target
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21592    360000.0
# 21593    400000.0
# 21594    402101.0
# 21595    400000.0
# 21596    325000.0
# Name: price, Length: 21597, dtype: float64

# %%
def regression(x,y):
    from sklearn.model_selection import train_test_split
    x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 1/3, random_state = 0)
    
    from sklearn.linear_model import LinearRegression
    p = LinearRegression()
    p.fit(x_train,y_train)
    
    print("Training Score",p.score(x_train,y_train))
    print("Test Score",p.score(x_test,y_test))
    
    return p

# %%
model= regression(x,y)
# Out:
# Training Score 0.69394092486636
# Test Score 0.7130822965445818

# %% [markdown]
# # Let's do normalization

# %%
x.max()
# Out:
# date             3.710000e+02
# bedrooms         3.300000e+01
# bathrooms        8.000000e+00
# sqft_living      1.354000e+04
# sqft_lot         1.651359e+06
# floors           3.500000e+00
# waterfront       1.000000e+00
# view             4.000000e+00
# condition        5.000000e+00
# grade            1.300000e+01
# sqft_above       9.410000e+03
# sqft_basement    4.820000e+03
# yr_built         2.015000e+03
# yr_renovated     2.015000e+03
# zipcode          9.819900e+04
# lat              4.777760e+01
# long            -1.213150e+02
# sqft_living15    6.210000e+03
# sqft_lot15       8.712000e+05
# dtype: float64

# %%
# import numpy as np
# np.max(y)

# %%
# y1= y/7700000.0

# %%
# regression(x,y)

# %%
from sklearn.preprocessing import Normalizer

# %%
k=Normalizer()

# %%
y=pd.DataFrame(y)              # convert the target y  in 2-D

# %%
k.fit(x)
# Out:
# Normalizer()

# %%
x2=k.transform(x)

# %%
k1=Normalizer()

# %%
k1.fit(y)
# Out:
# Normalizer()

# %%
y2=k1.transform(y)

# %%
regression(x2,y2)            #function calling
# Out:
# Training Score 1.0
# Test Score 1.0
# LinearRegression()

# %% [markdown]
# #    you are near to god (100%  accuracy).....
