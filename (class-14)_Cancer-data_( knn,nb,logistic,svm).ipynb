# %%
import pandas as pd

# %%
data= pd.read_csv("Cancer-data.csv")

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data= data.drop("id", axis= 1)

# %%
data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
k = LabelEncoder()
data["diagnosis"] = k.fit_transform(data["diagnosis"])

# %%
data
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            1        17.99         10.38          122.80     1001.0
# 1            1        20.57         17.77          132.90     1326.0
# 2            1        19.69         21.25          130.00     1203.0
# 3            1        11.42         20.38           77.58      386.1
# 4            1        20.29         14.34          135.10     1297.0
# ..         ...          ...           ...             ...        ...
# 564          1        21.56         22.39          142.00     1479.0
# 565          1        20.13         28.25          131.20     1261.0
# 566          1        16.60         28.08          108.30      858.1
# 567          1        20.60         29.33          140.10     1265.0
# 568          0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
data.max()
# Out:
# diagnosis                     1.00000
# radius_mean                  28.11000
# texture_mean                 39.28000
# perimeter_mean              188.50000
# area_mean                  2501.00000
# smoothness_mean               0.16340
# compactness_mean              0.34540
# concavity_mean                0.42680
# concave points_mean           0.20120
# symmetry_mean                 0.30400
# fractal_dimension_mean        0.09744
# radius_se                     2.87300
# texture_se                    4.88500
# perimeter_se                 21.98000
# area_se                     542.20000
# smoothness_se                 0.03113
# compactness_se                0.13540
# concavity_se                  0.39600
# concave points_se             0.05279
# symmetry_se                   0.07895
# fractal_dimension_se          0.02984
# radius_worst                 36.04000
# texture_worst                49.54000
# perimeter_worst             251.20000
# area_worst                 4254.00000
# ...

# %%
# data Normalization

data["radius_mean"]= data["radius_mean"] / 28.11000
data["texture_mean"]= data["texture_mean"] / 39.28000
data["perimeter_mean"]= data["perimeter_mean"] / 188.50000
data["area_mean"]= data["area_mean"] / 2501.00000
data["perimeter_se"]= data["perimeter_se"] / 21.98000
data["area_se"]= data["area_se"] / 542.20000
data["radius_worst"]= data["radius_worst"] / 36.04000
data["texture_worst"]= data["texture_worst"] / 49.54000
data["perimeter_worst"]= data["perimeter_worst"] / 251.20000
data["area_worst"]= data["area_worst"] / 4254.00000

# %%
data
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            1     0.639986      0.264257        0.651459   0.400240
# 1            1     0.731768      0.452393        0.705040   0.530188
# 2            1     0.700462      0.540988        0.689655   0.481008
# 3            1     0.406261      0.518839        0.411565   0.154378
# 4            1     0.721807      0.365071        0.716711   0.518593
# ..         ...          ...           ...             ...        ...
# 564          1     0.766987      0.570010        0.753316   0.591363
# 565          1     0.716115      0.719196        0.696021   0.504198
# 566          1     0.590537      0.714868        0.574536   0.343103
# 567          1     0.732835      0.746690        0.743236   0.505798
# 568          0     0.276058      0.624745        0.254218   0.072371
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
x= data.drop("diagnosis", axis= 1)              # x is feature
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       0.639986      0.264257        0.651459   0.400240          0.11840
# 1       0.731768      0.452393        0.705040   0.530188          0.08474
# 2       0.700462      0.540988        0.689655   0.481008          0.10960
# 3       0.406261      0.518839        0.411565   0.154378          0.14250
# 4       0.721807      0.365071        0.716711   0.518593          0.10030
# ..           ...           ...             ...        ...              ...
# 564     0.766987      0.570010        0.753316   0.591363          0.11100
# 565     0.716115      0.719196        0.696021   0.504198          0.09780
# 566     0.590537      0.714868        0.574536   0.343103          0.08455
# 567     0.732835      0.746690        0.743236   0.505798          0.11780
# 568     0.276058      0.624745        0.254218   0.072371          0.05263
#
# ...

# %%
y= data["diagnosis"]          #  y is  Target
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: diagnosis, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

# %%
x_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 60      0.361793      0.378819        0.342440   0.124710          0.11340
# 6       0.649235      0.508656        0.634483   0.415834          0.09463
# 8       0.462469      0.555499        0.464191   0.207837          0.12730
# 474     0.387051      0.397658        0.373528   0.143503          0.10070
# 320     0.364639      0.411914        0.352891   0.129628          0.10610
# ..           ...           ...             ...        ...              ...
# 277     0.669157      0.508656        0.641379   0.440624          0.08923
# 9       0.443259      0.612016        0.445464   0.190284          0.11860
# 359     0.335681      0.466395        0.317347   0.111395          0.10090
# 192     0.345784      0.463849        0.322175   0.115194          0.06950
# 559     0.409463      0.609216        0.395332   0.161335          0.09261
#
# ...

# %%
y_train
# Out:
# 60     0
# 6      1
# 8      1
# 474    0
# 320    0
#       ..
# 277    1
# 9      1
# 359    0
# 192    0
# 559    0
# Name: diagnosis, Length: 379, dtype: int32

# %%
def model(x , y):
        from sklearn.neighbors import KNeighborsClassifier
        knn = KNeighborsClassifier(n_neighbors=3)
        knn.fit(x, y) 

        from sklearn.naive_bayes import GaussianNB
        nb = GaussianNB()
        nb.fit(x, y)

        from sklearn.linear_model import LogisticRegression 
        logistic = LogisticRegression()
        logistic.fit(x, y)
        
        from sklearn.svm import SVC                   # "Support vector classifier"
        svm = SVC(kernel='linear', C=1E10)            #  c is for avoid hard margin  , we increase c value for avoid 
        svm.fit(x, y)                                 #   c is a parameter in SVM

        return knn, nb, logistic, svm

# %%
knn, nb, logistic, svm= model(x_train, y_train)              # model calling

# %%
def acc(knn, nb, logistic, svm, x, y):
        k= knn.score(x, y)
        print("KNN score is: ",k)

        n= nb.score(x, y)
        print("NB score is : ",n)

        l= logistic.score(x, y)
        print("logistic score is: ",l)
        
        s= svm.score(x, y)
        print("svm score is: ",s)

        if k>n and k>l:
            if k>s:
                print("\n KNN is Better")
                return knn

        elif n>l and n>s:
            print("\n NB is Better")
            return nb
        
        elif l>s:
            print("\n logistic is better")
            return logistic
        
        else:
            print("\n SVM is better")
            return svm

# %%
model= acc(knn, nb, logistic, svm, x_test, y_test)           # calling acc model
# Out:
# KNN score is:  0.9315789473684211
# NB score is :  0.9
# logistic score is:  0.9368421052631579
# svm score is:  0.9263157894736842
#
#  logistic is better
# C:\Users\NAFEES AHMAD\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
model.score(x_test, y_test)
# Out:
# 0.9368421052631579

# %% [markdown]
# # accurecy =  93%

# %%
model.score(x_train, y_train)
# Out:
# 0.9498680738786279

# %% [markdown]
# # Model is Ideal (Bios Varience Trade-off)

# %% [markdown]
# # Both Training and Test result is almost same
